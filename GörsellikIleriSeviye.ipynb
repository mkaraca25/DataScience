# %% [markdown]
# <a href="https://colab.research.google.com/github/mkaraca25/DataScience/blob/main/G%C3%B6rsellikIleriSeviye.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
numpyDizisi1=np.linspace(0,10,20)
numpyDizisi2=numpyDizisi1**2

# %%
(benimFigur,benimEksen)=plt.subplots()

# %%
(benimFigur,benimEksen)=plt.subplots()
benimEksen.plot(numpyDizisi1,numpyDizisi2,"g",alpha=0.4)
benimEksen.plot(numpyDizisi2,numpyDizisi1,"b")

# %%
(benimFigur,benimEksen)=plt.subplots()
benimEksen.plot(numpyDizisi1,numpyDizisi1+3,"g",alpha=0.4,linewidth=1.0)
benimEksen.plot(numpyDizisi1,numpyDizisi1+2,"b",linewidth=1.0)
benimEksen.plot(numpyDizisi1,numpyDizisi1+4,"#C96F23",linestyle="--")
benimEksen.plot(numpyDizisi1,numpyDizisi1+5,"#C96F23",linestyle=":")
benimEksen.plot(numpyDizisi1,numpyDizisi1+6,"#000000",linestyle=":",marker="o",markersize=5,markerfacecolor="red")

# %%
plt.scatter(numpyDizisi1,numpyDizisi2)

# %% [markdown]
# **Histogram**

# %%
yeniDizi=np.random.randint(0,100,50)

# %%
plt.hist(yeniDizi)
# Out:
# (array([3., 5., 8., 4., 4., 8., 4., 5., 4., 5.]),
#  array([ 4. , 13.2, 22.4, 31.6, 40.8, 50. , 59.2, 68.4, 77.6, 86.8, 96. ]),
#  <a list of 10 Patch objects>)

# %% [markdown]
# **Boxplot**

# %%
plt.boxplot(yeniDizi*2)
# Out:
# {'boxes': [<matplotlib.lines.Line2D at 0x7f615e7f4950>],
#  'caps': [<matplotlib.lines.Line2D at 0x7f615e7f8990>,
# ...
#  'fliers': [<matplotlib.lines.Line2D at 0x7f615e7fe9d0>],
#  'means': [],
#  'medians': [<matplotlib.lines.Line2D at 0x7f615e7fe490>],
#  'whiskers': [<matplotlib.lines.Line2D at 0x7f615e7f4ed0>,
#   <matplotlib.lines.Line2D at 0x7f615e7f8450>]}

# %% [markdown]
# **[For more...](https://matplotlib.org/stable/tutorials/index.html)**
