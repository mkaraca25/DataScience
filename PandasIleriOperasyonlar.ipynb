# %% [markdown]
# <a href="https://colab.research.google.com/github/mkaraca25/DataScience/blob/main/PandasIleriOperasyonlar.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
maasSozlugu=pd.DataFrame({"Departman":["Yazilim","Satis","Pazarlama","Yazilim"],
                          "Calisan Ismi":["Mayk","Ahmet","Mehmet","Burak"],
                          "Maas":[200,300,400,500]})
maasDtaFrame=pd.DataFrame(maasSozlugu)
maasDtaFrame
# Out:
#    Departman Calisan Ismi  Maas
# 0    Yazilim         Mayk   200
# 1      Satis        Ahmet   300
# 2  Pazarlama       Mehmet   400
# 3    Yazilim        Burak   500

# %%
maasDtaFrame["Departman"].unique()
# Out:
# array(['Yazilim', 'Satis', 'Pazarlama'], dtype=object)

# %%
maasDtaFrame["Departman"].nunique()
# Out:
# 3

# %%
maasDtaFrame["Departman"].value_counts()
# Out:
# Yazilim      2
# Pazarlama    1
# Satis        1
# Name: Departman, dtype: int64

# %%
def bruttenNete(maas):
  return maas*0.66

maasDtaFrame["Maas"].apply(bruttenNete)
# Out:
# 0    132.0
# 1    198.0
# 2    264.0
# 3    330.0
# Name: Maas, dtype: float64

# %%
maasSozlugu.isnull()
# Out:
#    Departman  Calisan Ismi   Maas
# 0      False         False  False
# 1      False         False  False
# 2      False         False  False
# 3      False         False  False

# %%
yeniData={"Karakter":["South Part","South Part","Simpson","Simpson","Simpson"],
          "Karakter ismi":["Cartman","Kenny","Kyle","Homer","Homer"],
          "Karakter Yas":[9,12,50,20,16]}
karakterDF=pd.DataFrame(yeniData)
karakterDF.pivot_table(values="Karakter Yas",index=["Karakter","Karakter ismi"])
# Out:
#                           Karakter Yas
# Karakter   Karakter ismi
# Simpson    Homer                    18
#            Kyle                     50
# South Part Cartman                   9
#            Kenny                    12

# %%
yeniData={"Karakter":["South Part","South Part","Simpson","Simpson","Simpson"],
          "Karakter ismi":["Cartman","Kenny","Kyle","Homer","Homer"],
          "Karakter Yas":[9,12,50,20,16]}
karakterDF=pd.DataFrame(yeniData)
karakterDF.pivot_table(values="Karakter Yas",index=["Karakter","Karakter ismi"],aggfunc=np.sum)
# Out:
#                           Karakter Yas
# Karakter   Karakter ismi
# Simpson    Homer                    36
#            Kyle                     50
# South Part Cartman                   9
#            Kenny                    12
